# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("RCN.xlsx")

# %%
data
# Out:
#      tweetDate                                            content  \
# 0   2023-04-01  Canadian Navy offers no strings attached progr...
# 1   2023-03-31           Bewverly Saftig      [Video] /W5D3igmOfh
# 2   2023-02-11  Due to lack of  Relic from the  will pick up t...
# 3   2023-03-08  Welcome to Port Alberni Terminals,    and  ! W...
# 4   2023-04-01  Canadian Navy offers no strings attached progr...
# ..         ...                                                ...
# 230 2023-03-24  🇨🇦⚓ The Royal Canadian Navy Halifax-class mult...
# 231 2023-03-24  🇨🇦⚓ Royal Canadian Navy Kingston-class maritim...
# 232 2023-03-26  Royal Canadian Navy frigate HMCS Montreal depa...
# 233 2023-03-30  /U2iUbtMe2V Wins Software Contract to Provide ...
# 234 2023-03-28  Announcing the Stadacona Band of the Royal Can...
#
#       twitterProfile                 query timestamp  sentiment_score  \
# 0         HandlerCND          canadiannavy  22:34:33          -0.6249
# 1         SamuelsCND          canadiannavy  14:22:34           0.0000
# 2          TerryToll          canadiannavy  22:25:46          -0.3182
# 3    PAPortAuthority          canadiannavy  17:16:48           0.6900
# 4         SamuelsCND          canadiannavy  22:34:35          -0.6249
# ..               ...                   ...       ...              ...
# 230   steffanwatkins  royal Canadian navy   12:28:15           0.0000
# 231   steffanwatkins  royal Canadian navy   13:05:29           0.1027
# 232    kldmr68501233  royal Canadian navy   15:59:50           0.0000
# 233   worldnews_guru  royal Canadian navy   16:53:51           0.5719
# 234    RoyalNSTattoo  royal Canadian navy   17:01:14           0.0000
#
#     sentiment
# 0    negative
# 1     neutral
# 2    negative
# 3    positive
# 4    negative
# ..        ...
# 230   neutral
# 231  positive
# 232   neutral
# 233  positive
# 234   neutral
#
# [235 rows x 7 columns]

# %% [markdown]
# lets look at the sentiment data:
# - bar graph to check the distribution of the sentiment
# - line graph to look at what the sentiment score looks like

# %%
sen_counts = data['sentiment'].value_counts()

# Bar plot
plt.bar(sen_counts.index, sen_counts)

# Add labels and title
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Sentiment Distribution')

# Display the plot
plt.show()

# %%
plt.plot(data['sentiment_score'])

# Add labels and title
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Line Graph')

# Display the plot
plt.show()

# %%
# !pip install --upgrade numpy
# !pip install --upgrade pandas
# Out:
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (1.24.3)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\user\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)

# %%
grouped_data = data.groupby('tweetDate').sum()
grouped_data['sentiment_score']
# Out:
# tweetDate
# 2021-09-01    0.8797
# 2022-12-19    0.0000
# 2023-01-01    0.0000
# 2023-01-07   -0.5994
# 2023-01-12    0.7964
# 2023-01-14    0.0000
# 2023-02-11   -0.3182
# 2023-02-18    2.2876
# 2023-02-28    1.0385
# 2023-03-03    0.6114
# 2023-03-08    0.6900
# 2023-03-10   -0.2481
# 2023-03-16    0.0000
# 2023-03-18    0.0000
# 2023-03-24   -0.8119
# 2023-03-25    0.1857
# 2023-03-26    4.1943
# 2023-03-27    4.6323
# 2023-03-28    2.2905
# 2023-03-29    0.6666
# 2023-03-30    4.6812
# 2023-03-31    7.6334
# 2023-04-01    1.8334
# Name: sentiment_score, dtype: float64

# %%
ss_data= pd.DataFrame(grouped_data['sentiment_score'])
ss = ss_data.reset_index()

print(ss)
# Out:
#     tweetDate  sentiment_score
# 0  2021-09-01           0.8797
# 1  2022-12-19           0.0000
# 2  2023-01-01           0.0000
# 3  2023-01-07          -0.5994
# 4  2023-01-12           0.7964
# 5  2023-01-14           0.0000
# 6  2023-02-11          -0.3182
# 7  2023-02-18           2.2876
# 8  2023-02-28           1.0385
# 9  2023-03-03           0.6114
# 10 2023-03-08           0.6900
# 11 2023-03-10          -0.2481
# 12 2023-03-16           0.0000
# 13 2023-03-18           0.0000
# 14 2023-03-24          -0.8119
# 15 2023-03-25           0.1857
# 16 2023-03-26           4.1943
# 17 2023-03-27           4.6323
# 18 2023-03-28           2.2905
# 19 2023-03-29           0.6666
# 20 2023-03-30           4.6812
# 21 2023-03-31           7.6334
# 22 2023-04-01           1.8334

# %%
date_array = ss['tweetDate'].values
ss_array = ss['sentiment_score'].values

# %%
plt.plot(date_array, ss_array)

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Sentiment Score')
plt.title('Sentiment score over Time')

# Display the plot
plt.show()

# %%
start_date = '2023-01-01'
end_date = '2023-04-01'

start_date = pd.to_datetime(start_date)
end_date = pd.to_datetime(end_date)

plt.plot(date_array, ss_array)

# Set the x-axis limits to the specified date range
plt.xlabel('Date')
plt.ylabel('Sentiment Score')
plt.title('Sentiment score over Time')
plt.xlim(start_date, end_date)
plt.xticks(rotation='vertical')

# Show the plot
plt.show()
